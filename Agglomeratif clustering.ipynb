# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import numpy as np

x = pd.DataFrame({
    'x':[32,10,22,58,81,21,29,75,15,32,11,76,45,43,25,68,74,19,42],
    'y':[18,32,38,48,51,6,57,29,64,60,36,73,38,53,42,63,12,23,23]
})

# %%
import scipy.cluster.hierarchy as shc

plt.figure(figsize=(10, 7))
plt.title("Dendograms")
dend = shc.dendrogram(shc.linkage(x, method='ward'))

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='ward')
cluster.fit_predict(x)
print(cluster.labels_)
# Out:
# [2 2 2 1 0 2 1 0 1 1 2 0 1 1 2 0 0 2 2]

# %%
plt.scatter(x['x'],x['y'], c=cluster.labels_, cmap='rainbow')
